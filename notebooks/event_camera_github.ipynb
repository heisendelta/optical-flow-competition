# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

project_dir = '/content/drive/My Drive/Colab Notebooks/event_camera_repo'

# %cd {project_dir}
# Out:
# /content/drive/My Drive/Colab Notebooks/event_camera_repo

# %%
# !git clone https://github.com/heisendelta/dl_comp.git temp_repo
# %cd temp_repo
# !git checkout event-camera-competition
# %cd ..

# !cp -r temp_repo/* .
# !rm -rf temp_repo
# !ls -la
# Out:
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 70 (delta 13), reused 4 (delta 4), pack-reused 33
# Receiving objects: 100% (70/70), 64.93 KiB | 685.00 KiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/drive/My Drive/Colab Notebooks/event_camera_repo/temp_repo
# Branch 'event-camera-competition' set up to track remote branch 'event-camera-competition' from 'origin'.
# Switched to a new branch 'event-camera-competition'
# /content/drive/My Drive/Colab Notebooks/event_camera_repo
# total 33
# drwx------ 2 root root 4096 Jul 10 11:28 configs
# drwx------ 2 root root 4096 Jul 10 09:56 data
# -rw------- 1 root root 6298 Jul 10 11:28 main.py
# drwx------ 2 root root 4096 Jul 10 11:28 notebooks
# drwx------ 2 root root 4096 Jul 10 10:20 outputs
# -rw------- 1 root root 5049 Jul 10 11:28 README.md
# -rw------- 1 root root  773 Jul 10 11:28 requirements.txt
# drwx------ 3 root root 4096 Jul 10 11:28 src

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 39.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 41.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 40.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 26.7 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.

# %%
# !python3 main.py
# Out:
# data/test/seq_1/events_left/events.h5 ['events', 'ms_to_idx', 't_offset']
# events/p
# events/x
# events/y
# events/t
# data/train/seq_2/events_left/events.h5 ['events', 'ms_to_idx', 't_offset']
# events/p
# events/x
# events/y
# events/t
# data/train/seq_1/events_left/events.h5 ['events', 'ms_to_idx', 't_offset']
# events/p
# events/x
# events/y
# events/t
# data/train/seq_3/events_left/events.h5 ['events', 'ms_to_idx', 't_offset']
# events/p
# events/x
# events/y
# events/t
# on epoch: 1
#   0% 0/126 [00:00<?, ?it/s]^C

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Verify GPU availability
print("Is CUDA available:", torch.cuda.is_available())
print("Number of GPUs:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# Is CUDA available: True
# Number of GPUs: 1
# GPU Name: Tesla T4
